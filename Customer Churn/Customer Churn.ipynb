# %%
import pandas as pd
import os
folder_path = "C:\\Users\\kolke\\Documents\\Machine Learning\\datasets\\customer churn data"
os.listdir(folder_path)
# Out:
# ['customer churn.csv']

# %%
file_path = os.path.join(folder_path, os.listdir(folder_path)[0])
file_path
# Out:
# 'C:\\Users\\kolke\\Documents\\Machine Learning\\datasets\\customer churn data\\customer churn.csv'

# %%
df = pd.read_csv(file_path)

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.drop(["customerID"], axis = 1, inplace = True)

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.countplot(x = "Churn", data = df)
plt.title("churn dist")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_enc = LabelEncoder()

# %%
df.head()
# Out:
#    gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  Female              0     Yes         No       1           No
# 1    Male              0      No         No      34          Yes
# 2    Male              0      No         No       2          Yes
# 3    Male              0      No         No      45           No
# 4  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0  No phone service             DSL             No          Yes
# 1                No             DSL            Yes           No
# 2                No             DSL            Yes          Yes
# 3  No phone service             DSL            Yes           No
# 4                No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   gender            7043 non-null   object
#  1   SeniorCitizen     7043 non-null   int64
#  2   Partner           7043 non-null   object
#  3   Dependents        7043 non-null   object
#  4   tenure            7043 non-null   int64
#  5   PhoneService      7043 non-null   object
#  6   MultipleLines     7043 non-null   object
#  7   InternetService   7043 non-null   object
#  8   OnlineSecurity    7043 non-null   object
#  9   OnlineBackup      7043 non-null   object
#  10  DeviceProtection  7043 non-null   object
#  11  TechSupport       7043 non-null   object
#  12  StreamingTV       7043 non-null   object
#  13  StreamingMovies   7043 non-null   object
#  14  Contract          7043 non-null   object
#  15  PaperlessBilling  7043 non-null   object
# ...

# %%
X = df.drop("Churn", axis = 1)
Y = df["Churn"]

df_minority = df[df["Churn"] == "Yes"]
df_majority = df[df["Churn"] == "No"]

# %%
from sklearn.utils import resample

# %%
df_majority_downsampled = resample(df_majority, 
                                   replace = False,
                                   n_samples = len(df_minority),
                                   random_state = 42
                                  )
df_balanced = pd.concat([df_majority_downsampled, df_minority])

# %%
df_balanced.head()
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2134  Female              0      No         No       1          Yes
# 2693    Male              0      No         No      72          Yes
# 1679    Male              1      No        Yes       7          Yes
# 5998    Male              0     Yes         No      48          Yes
# 6798  Female              0      No         No      13          Yes
#
#      MultipleLines InternetService       OnlineSecurity         OnlineBackup  \
# 2134            No              No  No internet service  No internet service
# 2693            No              No  No internet service  No internet service
# 1679            No             DSL                   No                   No
# 5998            No              No  No internet service  No internet service
# 6798            No     Fiber optic                   No                   No
#
#          DeviceProtection          TechSupport          StreamingTV  \
# ...

# %%
sns.countplot(x = "Churn", data = df_balanced)
plt.title("churn dist")
plt.show()

# %%
df_balanced.isna().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df_balanced.drop('TotalCharges', axis = 1, inplace = True)

# %%
encoders = {}

for col in df_balanced.select_dtypes(include = ["object"]).columns:
    enc = LabelEncoder()
    df_balanced[col] = enc.fit_transform(df_balanced[col])
    encoders[col] = enc

# %%
new_data = df_balanced.drop("Churn", axis = 1)
new_labels = df_balanced["Churn"]

# %%
from sklearn.model_selection import train_test_split as TTS
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score
import joblib

# %%
train_data, test_data, train_labels, test_labels = TTS(new_data, new_labels, train_size = 0.8, shuffle = True)

# %%
scaler = StandardScaler()
train_data = scaler.fit_transform(train_data)
test_data = scaler.fit_transform(test_data)

# %%
model = LogisticRegression()
model.fit(train_data, train_labels)

pred_labels = model.predict(test_data)

# %%
print("acc", accuracy_score(test_labels, pred_labels))
# Out:
# acc 0.7834224598930482

# %%
classification_report(test_labels, pred_labels)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.79      0.77      0.78       373\n           1       0.78      0.80      0.79       375\n\n    accuracy                           0.78       748\n   macro avg       0.78      0.78      0.78       748\nweighted avg       0.78      0.78      0.78       748\n'

# %%
encoders
# Out:
# {'gender': LabelEncoder(),
#  'Partner': LabelEncoder(),
#  'Dependents': LabelEncoder(),
#  'PhoneService': LabelEncoder(),
#  'MultipleLines': LabelEncoder(),
#  'InternetService': LabelEncoder(),
#  'OnlineSecurity': LabelEncoder(),
#  'OnlineBackup': LabelEncoder(),
#  'DeviceProtection': LabelEncoder(),
#  'TechSupport': LabelEncoder(),
#  'StreamingTV': LabelEncoder(),
#  'StreamingMovies': LabelEncoder(),
#  'Contract': LabelEncoder(),
#  'PaperlessBilling': LabelEncoder(),
#  'PaymentMethod': LabelEncoder(),
#  'Churn': LabelEncoder()}

# %%
joblib.dump(model, "churn_model.pkl")
joblib.dump(scaler, "scaler.pkl")
joblib.dump(encoders, "label_enc.pkl")
# Out:
# ['label_enc.pkl']
